# %% [markdown]
# <a href="https://colab.research.google.com/github/Vishalization/optimisation_resNet50/blob/main/optimization_adamw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install disarray
# Out:
# Collecting disarray
#   Downloading disarray-0.2.0-py2.py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: pandas>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from disarray) (2.2.2)
# Requirement already satisfied: numpy>=0.14.2 in /usr/local/lib/python3.12/dist-packages (from disarray) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.23.0->disarray) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.23.0->disarray) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.23.0->disarray) (2026.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=0.23.0->disarray) (1.17.0)
# Downloading disarray-0.2.0-py2.py3-none-any.whl (6.8 kB)
# Installing collected packages: disarray
# Successfully installed disarray-0.2.0

# %%
#extract Dataset
import zipfile
import os

zip_path = "/content/drive/MyDrive/skin_split.rar"

extract_path = "/content/dataset"
os.makedirs(extract_path, exist_ok=True)

# !unrar x "{zip_path}" "{extract_path}"

# %%
#Imports
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D

from tensorflow.keras.optimizers import Adam, AdamW, SGD

from tensorflow.keras.callbacks import (
    ReduceLROnPlateau,
    EarlyStopping,
    ModelCheckpoint
)

from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    accuracy_score,
    f1_score,
    precision_score,
    recall_score
)

from sklearn.utils.class_weight import compute_class_weight

# %%
#Fix random seed
SEED = 42

np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
#Dataset Paths
train_dir = "/content/dataset/skin_split/train"
test_dir = "/content/dataset/skin_split/test"

# %%
#Baseline Data Generator
train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

# %%
#Train Generator
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224,224),
    batch_size=32,
    class_mode='categorical',
    subset='training',
    shuffle=True,
    seed=SEED
)
# Out:
# Found 6411 images belonging to 7 classes.

# %%
#Val Generator
val_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224,224),
    batch_size=32,
    class_mode='categorical',
    subset='validation',
    shuffle=False,
    seed=SEED
)
# Out:
# Found 1599 images belonging to 7 classes.

# %%
#Test Generator
test_datagen = ImageDataGenerator(
    rescale=1./255
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224,224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 2005 images belonging to 7 classes.

# %%
#Class Weight
class_labels = train_generator.classes

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(class_labels),
    y=class_labels
)

class_weights = dict(enumerate(class_weights))

print(class_weights)
# Out:
# {0: np.float64(4.3820915926179085), 1: np.float64(2.7837603126356925), 2: np.float64(1.3009334415584415), 3: np.float64(12.376447876447877), 4: np.float64(1.2863162118780096), 5: np.float64(0.2133870323525496), 6: np.float64(10.06436420722135)}

# %%
#Build  Model
from tensorflow.keras.applications import ResNet50

from tensorflow.keras.layers import (
    Dense,
    Dropout,
    GlobalAveragePooling2D
)

from tensorflow.keras.models import Model

from tensorflow.keras.regularizers import l2

base_model = ResNet50(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)

# Fine-tune entire network
base_model.trainable = True

x = base_model.output

x = GlobalAveragePooling2D()(x)

x = Dense(
    256,
    activation='relu',
    kernel_regularizer=l2(0.001)
)(x)

x = Dropout(0.5)(x)

output = Dense(
    7,
    activation='softmax'
)(x)

model = Model(
    inputs=base_model.input,
    outputs=output
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Custom Focal Loss

def focal_loss(gamma=2.0, alpha=0.25):

    def focal_loss_fixed(y_true, y_pred):

        epsilon = 1e-7

        y_pred = tf.clip_by_value(
            y_pred,
            epsilon,
            1.0 - epsilon
        )

        cross_entropy = -y_true * tf.math.log(y_pred)

        loss = alpha * tf.pow(
            1 - y_pred,
            gamma
        ) * cross_entropy

        return tf.reduce_mean(
            tf.reduce_sum(loss, axis=1)
        )

    return focal_loss_fixed

# %%
model.compile(

    optimizer=AdamW(
        learning_rate=1e-4,
        weight_decay=1e-5
    ),

    loss=focal_loss(
        gamma=2.0,
        alpha=0.25
    ),

    metrics=['accuracy']
)

# %%
#Callbacks

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=2,
    verbose=1,
    min_lr=1e-7
)

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True,
    verbose=1
)

checkpoint = ModelCheckpoint(
    "best_scheduler_model.keras",
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1
)

# %%
#Train Scheduler  Model

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=15,
    class_weight=class_weights,
    callbacks=[reduce_lr, early_stop, checkpoint]
)
# Out:
# Epoch 1/15
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step - accuracy: 0.6469 - loss: 0.6214
# Epoch 1: val_accuracy improved from None to 0.67042, saving model to best_scheduler_model.keras
#
# Epoch 1: finished saving model to best_scheduler_model.keras
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 197s 625ms/step - accuracy: 0.7139 - loss: 0.5655 - val_accuracy: 0.6704 - val_loss: 1.0586 - learning_rate: 1.0000e-04
# Epoch 2/15
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.8132 - loss: 0.4698
# Epoch 2: val_accuracy did not improve from 0.67042
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 77s 379ms/step - accuracy: 0.8166 - loss: 0.4561 - val_accuracy: 0.6704 - val_loss: 0.9600 - learning_rate: 1.0000e-04
# Epoch 3/15
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.8699 - loss: 0.3960
# Epoch 3: val_accuracy did not improve from 0.67042
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 73s 364ms/step - accuracy: 0.8696 - loss: 0.3848 - val_accuracy: 0.6704 - val_loss: 0.7549 - learning_rate: 1.0000e-04
# Epoch 4/15
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.9134 - loss: 0.3352
# Epoch 4: val_accuracy did not improve from 0.67042
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 73s 363ms/step - accuracy: 0.9176 - loss: 0.3241 - val_accuracy: 0.6704 - val_loss: 0.8298 - learning_rate: 1.0000e-04
# Epoch 5/15
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - accuracy: 0.9532 - loss: 0.2834
# Epoch 5: val_accuracy improved from 0.67042 to 0.70169, saving model to best_scheduler_model.keras
#
# Epoch 5: finished saving model to best_scheduler_model.keras
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 76s 376ms/step - accuracy: 0.9420 - loss: 0.2765 - val_accuracy: 0.7017 - val_loss: 0.5144 - learning_rate: 1.0000e-04
# Epoch 6/15
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.9477 - loss: 0.2472
# Epoch 6: val_accuracy improved from 0.70169 to 0.79425, saving model to best_scheduler_model.keras
#
# Epoch 6: finished saving model to best_scheduler_model.keras
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 76s 375ms/step - accuracy: 0.9488 - loss: 0.2392 - val_accuracy: 0.7942 - val_loss: 0.3380 - learning_rate: 1.0000e-04
# Epoch 7/15
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.9503 - loss: 0.2139
# Epoch 7: val_accuracy improved from 0.79425 to 0.79862, saving model to best_scheduler_model.keras
#
# Epoch 7: finished saving model to best_scheduler_model.keras
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 76s 376ms/step - accuracy: 0.9599 - loss: 0.2037 - val_accuracy: 0.7986 - val_loss: 0.2746 - learning_rate: 1.0000e-04
# Epoch 8/15
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.9675 - loss: 0.1806
# Epoch 8: val_accuracy did not improve from 0.79862
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 74s 365ms/step - accuracy: 0.9627 - loss: 0.1750 - val_accuracy: 0.7267 - val_loss: 0.2681 - learning_rate: 1.0000e-04
# Epoch 9/15
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.9614 - loss: 0.1545
# Epoch 9: val_accuracy improved from 0.79862 to 0.81113, saving model to best_scheduler_model.keras
#
# Epoch 9: finished saving model to best_scheduler_model.keras
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 75s 375ms/step - accuracy: 0.9616 - loss: 0.1496 - val_accuracy: 0.8111 - val_loss: 0.2377 - learning_rate: 1.0000e-04
# Epoch 10/15
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - accuracy: 0.9770 - loss: 0.1273
# Epoch 10: val_accuracy improved from 0.81113 to 0.82051, saving model to best_scheduler_model.keras
#
# Epoch 10: finished saving model to best_scheduler_model.keras
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 75s 374ms/step - accuracy: 0.9752 - loss: 0.1229 - val_accuracy: 0.8205 - val_loss: 0.2071 - learning_rate: 1.0000e-04
# Epoch 11/15
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.9800 - loss: 0.1068
# Epoch 11: val_accuracy did not improve from 0.82051
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 73s 364ms/step - accuracy: 0.9842 - loss: 0.1016 - val_accuracy: 0.7986 - val_loss: 0.2325 - learning_rate: 1.0000e-04
# Epoch 12/15
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.9716 - loss: 0.0948
# Epoch 12: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 12: val_accuracy did not improve from 0.82051
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 73s 361ms/step - accuracy: 0.9513 - loss: 0.0977 - val_accuracy: 0.7123 - val_loss: 0.2276 - learning_rate: 1.0000e-04
# Epoch 13/15
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.9754 - loss: 0.0810
# Epoch 13: val_accuracy improved from 0.82051 to 0.85991, saving model to best_scheduler_model.keras
#
# Epoch 13: finished saving model to best_scheduler_model.keras
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 76s 376ms/step - accuracy: 0.9813 - loss: 0.0769 - val_accuracy: 0.8599 - val_loss: 0.1517 - learning_rate: 5.0000e-05
# Epoch 14/15
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.9941 - loss: 0.0682
# Epoch 14: val_accuracy did not improve from 0.85991
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 74s 366ms/step - accuracy: 0.9955 - loss: 0.0664 - val_accuracy: 0.8505 - val_loss: 0.1535 - learning_rate: 5.0000e-05
# Epoch 15/15
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - accuracy: 0.9979 - loss: 0.0613
# Epoch 15: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 15: val_accuracy did not improve from 0.85991
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 73s 364ms/step - accuracy: 0.9981 - loss: 0.0596 - val_accuracy: 0.8555 - val_loss: 0.1563 - learning_rate: 5.0000e-05
# Restoring model weights from the end of the best epoch: 13.

# %%
df=pd.DataFrame(history.history)
df.to_csv('hist.csv')

# %%
metrics = pd.DataFrame(history.history)
metrics[["loss","val_loss"]].plot()
# Out:
# <Axes: >

# %%
metrics[["accuracy","val_accuracy"]].plot()
# Out:
# <Axes: >

# %%
model.evaluate(test_generator)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 22s 351ms/step - accuracy: 0.8608 - loss: 0.1380
# [0.1380162388086319, 0.8608478903770447]

# %%
predictions = model.predict(test_generator, verbose=1)
predictions = predictions.argmax(axis=1)

test_labels = test_generator.classes
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 22s 293ms/step

# %%
import sklearn
from sklearn.metrics import classification_report, confusion_matrix

cm = confusion_matrix(test_labels, predictions)

# %%
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=True,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
        print(cm)

    plt.figure(figsize=(7,7))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()


cm_plot_labels =['AKIEC','BCC','BKL','DF','MEL','NV','VASC']
plot_confusion_matrix(cm, cm_plot_labels, title='Confusion Matrix', normalize=True)
# Out:
# Normalized confusion matrix

# %%
import disarray

df_cm = pd.DataFrame(
    cm,
    index=['AKIEC','BCC','BKL','DF','MEL','NV','VASC'],
    columns=['AKIEC','BCC','BKL','DF','MEL','NV','VASC']
)

metrics_focal = df_cm.da.export_metrics()

metrics_focal
# Out:
#                               AKIEC       BCC       BKL        DF       MEL  \
# accuracy                   0.978554  0.974065  0.941646  0.992020  0.933167
# f1                         0.612613  0.750000  0.719424  0.600000  0.661616
# false_discovery_rate       0.244444  0.257143  0.238579  0.294118  0.242775
# false_negative_rate        0.484848  0.242718  0.318182  0.478261  0.412556
# false_positive_rate        0.005673  0.014196  0.026331  0.002523  0.023569
# negative_predictive_value  0.983673  0.986842  0.961283  0.994467  0.949782
# positive_predictive_value  0.755556  0.742857  0.761421  0.705882  0.757225
# precision                  0.755556  0.742857  0.761421  0.705882  0.757225
# recall                     0.515152  0.757282  0.681818  0.521739  0.587444
# sensitivity                0.515152  0.757282  0.681818  0.521739  0.587444
# specificity                0.994327  0.985804  0.973669  0.997477  0.976431
# true_negative_rate         0.994327  0.985804  0.973669  0.997477  0.976431
# true_positive_rate         0.515152  0.757282  0.681818  0.521739  0.587444
#
#                                  NV      VASC  micro-average
# accuracy                   0.906733  0.995511       0.960242
# f1                         0.932806  0.836364       0.860848
# false_discovery_rate       0.099861  0.115385       0.139152
# false_negative_rate        0.032066  0.206897       0.139152
# false_positive_rate        0.216867  0.001518       0.023192
# negative_predictive_value  0.923623  0.996968       0.976808
# positive_predictive_value  0.900139  0.884615       0.860848
# precision                  0.900139  0.884615       0.860848
# recall                     0.967934  0.793103       0.860848
# sensitivity                0.967934  0.793103       0.860848
# specificity                0.783133  0.998482       0.976808
# true_negative_rate         0.783133  0.998482       0.976808
# true_positive_rate         0.967934  0.793103       0.860848

# %%
metrics_focal.to_csv("focal_loss_metrics.csv")
