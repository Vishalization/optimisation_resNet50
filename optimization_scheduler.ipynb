# %% [markdown]
# <a href="https://colab.research.google.com/github/Vishalization/optimisation_resNet50/blob/main/optimization_scheduler.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install disarray

# %%
#extract Dataset
import zipfile
import os

zip_path = "/content/drive/MyDrive/skin_split.rar"

extract_path = "/content/dataset"
os.makedirs(extract_path, exist_ok=True)

# !unrar x "{zip_path}" "{extract_path}"

# %%
#Imports
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D

from tensorflow.keras.optimizers import Adam, AdamW, SGD

from tensorflow.keras.callbacks import (
    ReduceLROnPlateau,
    EarlyStopping,
    ModelCheckpoint
)

from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    accuracy_score,
    f1_score,
    precision_score,
    recall_score
)

from sklearn.utils.class_weight import compute_class_weight

# %%
#Fix random seed
SEED = 42

np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
#Dataset Paths
train_dir = "/content/dataset/skin_split/train"
test_dir = "/content/dataset/skin_split/test"

# %%
#Baseline Data Generator
train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

# %%
#Train Generator
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224,224),
    batch_size=32,
    class_mode='categorical',
    subset='training',
    shuffle=True,
    seed=SEED
)
# Out:
# Found 6411 images belonging to 7 classes.

# %%
#Val Generator
val_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224,224),
    batch_size=32,
    class_mode='categorical',
    subset='validation',
    shuffle=False,
    seed=SEED
)
# Out:
# Found 1599 images belonging to 7 classes.

# %%
#Test Generator
test_datagen = ImageDataGenerator(
    rescale=1./255
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224,224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 2005 images belonging to 7 classes.

# %%
#Class Weight
class_labels = train_generator.classes

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(class_labels),
    y=class_labels
)

class_weights = dict(enumerate(class_weights))

print(class_weights)
# Out:
# {0: np.float64(4.3820915926179085), 1: np.float64(2.7837603126356925), 2: np.float64(1.3009334415584415), 3: np.float64(12.376447876447877), 4: np.float64(1.2863162118780096), 5: np.float64(0.2133870323525496), 6: np.float64(10.06436420722135)}

# %%
#Build Schedular Model
from tensorflow.keras.applications import ResNet50

from tensorflow.keras.layers import (
    Dense,
    Dropout,
    GlobalAveragePooling2D
)

from tensorflow.keras.models import Model

from tensorflow.keras.regularizers import l2

base_model = ResNet50(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)

# Fine-tune entire network
base_model.trainable = True

x = base_model.output

x = GlobalAveragePooling2D()(x)

x = Dense(
    256,
    activation='relu',
    kernel_regularizer=l2(0.001)
)(x)

x = Dropout(0.5)(x)

output = Dense(
    7,
    activation='softmax'
)(x)

model = Model(
    inputs=base_model.input,
    outputs=output
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step

# %%
# Custom Focal Loss

def focal_loss(gamma=2.0, alpha=0.25):

    def focal_loss_fixed(y_true, y_pred):

        epsilon = 1e-7

        y_pred = tf.clip_by_value(
            y_pred,
            epsilon,
            1.0 - epsilon
        )

        cross_entropy = -y_true * tf.math.log(y_pred)

        loss = alpha * tf.pow(
            1 - y_pred,
            gamma
        ) * cross_entropy

        return tf.reduce_mean(
            tf.reduce_sum(loss, axis=1)
        )

    return focal_loss_fixed

# %%
model.compile(
    optimizer=Adam(learning_rate=1e-4),

    loss=focal_loss(
        gamma=2.0,
        alpha=0.25
    ),

    metrics=['accuracy']
)

# %%
#Callbacks

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=2,
    verbose=1,
    min_lr=1e-7
)

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True,
    verbose=1
)

checkpoint = ModelCheckpoint(
    "best_scheduler_model.keras",
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1
)

# %%
#Train Scheduler  Model

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=15,
    class_weight=class_weights,
    callbacks=[reduce_lr, early_stop, checkpoint]
)
# Out:
# Epoch 1/15
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - accuracy: 0.6544 - loss: 0.6131
# Epoch 1: val_accuracy improved from None to 0.67042, saving model to best_scheduler_model.keras
#
# Epoch 1: finished saving model to best_scheduler_model.keras
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 191s 605ms/step - accuracy: 0.7197 - loss: 0.5619 - val_accuracy: 0.6704 - val_loss: 1.1534 - learning_rate: 1.0000e-04
# Epoch 2/15
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.8144 - loss: 0.4640
# Epoch 2: val_accuracy did not improve from 0.67042
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 76s 377ms/step - accuracy: 0.8230 - loss: 0.4521 - val_accuracy: 0.6704 - val_loss: 1.2808 - learning_rate: 1.0000e-04
# Epoch 3/15
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.8740 - loss: 0.3936
# Epoch 3: val_accuracy did not improve from 0.67042
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 72s 355ms/step - accuracy: 0.8704 - loss: 0.3826 - val_accuracy: 0.6704 - val_loss: 0.9327 - learning_rate: 1.0000e-04
# Epoch 4/15
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.9184 - loss: 0.3351
# Epoch 4: val_accuracy did not improve from 0.67042
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 72s 358ms/step - accuracy: 0.9134 - loss: 0.3250 - val_accuracy: 0.6704 - val_loss: 0.7145 - learning_rate: 1.0000e-04
# Epoch 5/15
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.9493 - loss: 0.2826
# Epoch 5: val_accuracy improved from 0.67042 to 0.69043, saving model to best_scheduler_model.keras
#
# Epoch 5: finished saving model to best_scheduler_model.keras
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 83s 413ms/step - accuracy: 0.9429 - loss: 0.2758 - val_accuracy: 0.6904 - val_loss: 0.5634 - learning_rate: 1.0000e-04
# Epoch 6/15
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.9606 - loss: 0.2425
# Epoch 6: val_accuracy improved from 0.69043 to 0.76923, saving model to best_scheduler_model.keras
#
# Epoch 6: finished saving model to best_scheduler_model.keras
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 74s 368ms/step - accuracy: 0.9559 - loss: 0.2355 - val_accuracy: 0.7692 - val_loss: 0.3729 - learning_rate: 1.0000e-04
# Epoch 7/15
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.9626 - loss: 0.2098
# Epoch 7: val_accuracy improved from 0.76923 to 0.81301, saving model to best_scheduler_model.keras
#
# Epoch 7: finished saving model to best_scheduler_model.keras
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 74s 367ms/step - accuracy: 0.9565 - loss: 0.2036 - val_accuracy: 0.8130 - val_loss: 0.2829 - learning_rate: 1.0000e-04
# Epoch 8/15
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.9495 - loss: 0.1806
# Epoch 8: val_accuracy improved from 0.81301 to 0.83490, saving model to best_scheduler_model.keras
#
# Epoch 8: finished saving model to best_scheduler_model.keras
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 83s 414ms/step - accuracy: 0.9540 - loss: 0.1732 - val_accuracy: 0.8349 - val_loss: 0.2310 - learning_rate: 1.0000e-04
# Epoch 9/15
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.9785 - loss: 0.1484
# Epoch 9: val_accuracy did not improve from 0.83490
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 72s 358ms/step - accuracy: 0.9736 - loss: 0.1436 - val_accuracy: 0.7980 - val_loss: 0.2717 - learning_rate: 1.0000e-04
# Epoch 10/15
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - accuracy: 0.9758 - loss: 0.1288
# Epoch 10: val_accuracy did not improve from 0.83490
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 74s 365ms/step - accuracy: 0.9757 - loss: 0.1230 - val_accuracy: 0.8268 - val_loss: 0.2105 - learning_rate: 1.0000e-04
# Epoch 11/15
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.9737 - loss: 0.1098
# Epoch 11: val_accuracy did not improve from 0.83490
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 73s 365ms/step - accuracy: 0.9713 - loss: 0.1059 - val_accuracy: 0.7911 - val_loss: 0.2340 - learning_rate: 1.0000e-04
# Epoch 12/15
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 0.9721 - loss: 0.0936
# Epoch 12: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 12: val_accuracy did not improve from 0.83490
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 75s 370ms/step - accuracy: 0.9679 - loss: 0.0927 - val_accuracy: 0.4653 - val_loss: 0.3908 - learning_rate: 1.0000e-04
# Epoch 13/15
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.9485 - loss: 0.0880
# Epoch 13: val_accuracy improved from 0.83490 to 0.84553, saving model to best_scheduler_model.keras
#
# Epoch 13: finished saving model to best_scheduler_model.keras
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 76s 376ms/step - accuracy: 0.9685 - loss: 0.0803 - val_accuracy: 0.8455 - val_loss: 0.1456 - learning_rate: 5.0000e-05
# Epoch 14/15
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - accuracy: 0.9920 - loss: 0.0687
# Epoch 14: val_accuracy did not improve from 0.84553
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 73s 363ms/step - accuracy: 0.9933 - loss: 0.0672 - val_accuracy: 0.8343 - val_loss: 0.1641 - learning_rate: 5.0000e-05
# Epoch 15/15
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.9976 - loss: 0.0616
# Epoch 15: val_accuracy improved from 0.84553 to 0.85303, saving model to best_scheduler_model.keras
#
# Epoch 15: finished saving model to best_scheduler_model.keras
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 75s 373ms/step - accuracy: 0.9963 - loss: 0.0604 - val_accuracy: 0.8530 - val_loss: 0.1408 - learning_rate: 5.0000e-05
# Restoring model weights from the end of the best epoch: 15.

# %%
df=pd.DataFrame(history.history)
df.to_csv('hist.csv')

# %%
metrics = pd.DataFrame(history.history)
metrics[["loss","val_loss"]].plot()
# Out:
# <Axes: >

# %%
metrics[["accuracy","val_accuracy"]].plot()
# Out:
# <Axes: >

# %%
model.evaluate(test_generator)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 22s 352ms/step - accuracy: 0.8613 - loss: 0.1340
# [0.13398125767707825, 0.8613466620445251]

# %%
predictions = model.predict(test_generator, verbose=1)
predictions = predictions.argmax(axis=1)

test_labels = test_generator.classes
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 25s 314ms/step

# %%
import sklearn
from sklearn.metrics import classification_report, confusion_matrix

cm = confusion_matrix(test_labels, predictions)

# %%
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=True,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
        print(cm)

    plt.figure(figsize=(7,7))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()


cm_plot_labels =['AKIEC','BCC','BKL','DF','MEL','NV','VASC']
plot_confusion_matrix(cm, cm_plot_labels, title='Confusion Matrix', normalize=True)
# Out:
# Normalized confusion matrix

# %%
import disarray

df_cm = pd.DataFrame(
    cm,
    index=['AKIEC','BCC','BKL','DF','MEL','NV','VASC'],
    columns=['AKIEC','BCC','BKL','DF','MEL','NV','VASC']
)

metrics_focal = df_cm.da.export_metrics()

metrics_focal
# Out:
#                               AKIEC       BCC       BKL        DF       MEL  \
# accuracy                   0.979052  0.973566  0.935162  0.994015  0.933666
# f1                         0.700000  0.736318  0.716157  0.684211  0.627451
# false_discovery_rate       0.337838  0.244898  0.310924  0.133333  0.164179
# false_negative_rate        0.257576  0.281553  0.254545  0.434783  0.497758
# false_positive_rate        0.012893  0.012618  0.041457  0.001009  0.012346
# negative_predictive_value  0.991196  0.984793  0.968308  0.994975  0.940673
# positive_predictive_value  0.662162  0.755102  0.689076  0.866667  0.835821
# precision                  0.662162  0.755102  0.689076  0.866667  0.835821
# recall                     0.742424  0.718447  0.745455  0.565217  0.502242
# sensitivity                0.742424  0.718447  0.745455  0.565217  0.502242
# specificity                0.987107  0.987382  0.958543  0.998991  0.987654
# true_negative_rate         0.987107  0.987382  0.958543  0.998991  0.987654
# true_positive_rate         0.742424  0.718447  0.745455  0.565217  0.502242
#
#                                  NV      VASC  micro-average
# accuracy                   0.911222  0.996010       0.960385
# f1                         0.935460  0.862069       0.861347
# false_discovery_rate       0.089626  0.137931       0.138653
# false_negative_rate        0.038031  0.137931       0.138653
# false_positive_rate        0.191265  0.002024       0.023109
# negative_predictive_value  0.913265  0.997976       0.976891
# positive_predictive_value  0.910374  0.862069       0.861347
# precision                  0.910374  0.862069       0.861347
# recall                     0.961969  0.862069       0.861347
# sensitivity                0.961969  0.862069       0.861347
# specificity                0.808735  0.997976       0.976891
# true_negative_rate         0.808735  0.997976       0.976891
# true_positive_rate         0.961969  0.862069       0.861347

# %%
metrics_focal.to_csv("focal_loss_metrics.csv")
